# %%
### EXPERIMENTS TO PLOT ###
prefix = "child"
experiments = [
    f"{prefix}_experiment_A1",
    f"{prefix}_experiment_A2",
    f"{prefix}_experiment_B1",
    f"{prefix}_experiment_B2",
    f"{prefix}_experiment_C1",
    f"{prefix}_experiment_C2"
]

# List of synthetic datasets to evaluate (without path or .csv extension)
synthetic_datasets = [
    f"{prefix}_ctgan",
    f"{prefix}_begreat",
    f"{prefix}_tvae",
    f"{prefix}_tabddpm",
    "synthetic_llm_40_shots",
    "synthetic_llm_60_shots",
    "synthetic_llm_80_shots",
    "synthetic_llm_100_shots",
    "synthetic_llm_120_shots",
    "synthetic_llm_140_shots",
    "synthetic_llm_160_shots"
]

dataset = "datasets/child.csv"

# %%
from plot_evaluation_graphs import run
run(
    dataset=dataset,
    experiments=experiments,
    synthetic_datasets=synthetic_datasets
)
